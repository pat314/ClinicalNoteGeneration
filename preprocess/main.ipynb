# %% [markdown]
# # Phase 1

# %%
# Import necessary libraries
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("SOAP_notes/train.csv")
df.info()         # print general informations
print("df label partitionf for", np.unique(df["Label"]), ":", np.bincount(df["Label"]))

assert len(df["ID"]) == len(df)
assert len(np.unique(df["Label"])) == 4

df                # print dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      153 non-null    int64
#  1   Text    153 non-null    object
#  2   Label   153 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 3.7+ KB
# df label partitionf for [0 1 2 3] : [37 39 37 40]
#       ID                                               Text  Label
# 0    102                                To Newborn Nursery       3
# 1    140   Toprol . Lasix . Digoxin . Coumadin . Flovent...      3
# 2     81   Of note  Na 133   K 4   WBC 8.82   hematocrit...      1
# 3      9  Feedings at discharge  Similac 22 calories per...      2
# 4    133   Pentamidine 300 mg IV q. 36 hours   Pentamidi...      3
# ..   ...                                                ...    ...
# 148   78   ON ADMISSION  Temperature 98.8   heart rate 6...      1
# ...

# %%
df["Processed text"] = [df["Text"][i].split(" . ") for i in range(len(df))]

# %%
df
# Out:
#       ID                                               Text  Label  \
# 0    102                                To Newborn Nursery       3
# 1    140   Toprol . Lasix . Digoxin . Coumadin . Flovent...      3
# 2     81   Of note  Na 133   K 4   WBC 8.82   hematocrit...      1
# 3      9  Feedings at discharge  Similac 22 calories per...      2
# 4    133   Pentamidine 300 mg IV q. 36 hours   Pentamidi...      3
# ..   ...                                                ...    ...
# 148   78   ON ADMISSION  Temperature 98.8   heart rate 6...      1
# 149   13   Docusate sodium 100 mg p.o. b.i.d. Ursodiol 3...      2
# 150  137   Synthroid   Prilosec 20 mg p.o.   Fioricet   ...      3
# 151   54   He was a well-developed   well-nourished man ...      1
# 152  178   Breast cancer   status post lumpectomy  Mitra...      0
#
#                                         Processed text
# 0                                [To Newborn Nursery ]
# ...

# %%
df = pd.read_csv("SOAP_notes/test.csv")
df.info()         # print general informations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           51 non-null     int64
#  1   Text         51 non-null     object
#  2   Label        51 non-null     int64
#  3   Unnamed: 3   0 non-null      float64
#  4   Unnamed: 4   0 non-null      float64
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   0 non-null      float64
#  7   Unnamed: 7   0 non-null      float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  0 non-null      float64
#  13  Unnamed: 13  0 non-null      float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 5.7+ KB

# %%
df
# Out:
#      ID                                               Text  Label  Unnamed: 3  \
# 0   152   h  o nephrolithiasis s  p lithotripsy and h  ...      0         NaN
# 1    48   Colace 100 mg p.o. b.i.d.   Folate 1 mg q.d. ...      2         NaN
# 2   173   Atrial fibrillation secondary to hyperthyroid...      0         NaN
# 3    83   On admission   in general   the patient was i...      1         NaN
# 4    26   Metastatic gallbladder cancer . Status post c...      2         NaN
# 5   165   As above . PAST SURGICAL HISTORY   As above  ...      0         NaN
# 6   206   VITAL SIGNS  Temp 98.5   heart rate 74   BP 1...      1         NaN
# 7    59   In Clinic his cervical spine examination was ...      1         NaN
# 8   154   1  Cardiovascular  The patient was admitted f...      0         NaN
# 9    69   Notable for sodium 141   potassium 4.2   chlo...      1         NaN
# 10   32   Percocet one to two tablets p.o. q.4-6h. p.r....      2         NaN
# ...

# %%
for col in df.columns : 
  #print(col, len(df[df[col] == np.nan]))
  if type(df[col][0])!=str and len([i for i in range(len(df)) if np.isnan(df[col][i])==True]) > len(df)//2: 
    df.drop(col,axis=1,inplace=True)

# %%
df
# Out:
#      ID                                               Text  Label
# 0   152   h  o nephrolithiasis s  p lithotripsy and h  ...      0
# 1    48   Colace 100 mg p.o. b.i.d.   Folate 1 mg q.d. ...      2
# 2   173   Atrial fibrillation secondary to hyperthyroid...      0
# 3    83   On admission   in general   the patient was i...      1
# 4    26   Metastatic gallbladder cancer . Status post c...      2
# 5   165   As above . PAST SURGICAL HISTORY   As above  ...      0
# 6   206   VITAL SIGNS  Temp 98.5   heart rate 74   BP 1...      1
# 7    59   In Clinic his cervical spine examination was ...      1
# 8   154   1  Cardiovascular  The patient was admitted f...      0
# 9    69   Notable for sodium 141   potassium 4.2   chlo...      1
# 10   32   Percocet one to two tablets p.o. q.4-6h. p.r....      2
# 11   21   Allergies include AMOXICILLIN and CODEINE . M...      2
# 12  148  1. GI  Patient was transfused 2 units of packe...      0
# ...

# %% [markdown]
# ---
# # Phase 2

# %%
train = pd.read_csv("SOAP_notes/train.csv")
test = pd.read_csv("SOAP_notes/test.csv")

# %%
train["Processed text"] = [train["Text"][i].split(" . ") for i in range(len(train))]   # Split text

# %%
train["Processed text"][0]
# Out:
# ['To Newborn Nursery ']

# %%
np.argmax([len(train["Processed text"][i]) for i in range(len(train))])
# Out:
# 58

# %%
from tools.utterance_encoder import bcbert_encoder
from tools.side import mean_sample

# %%
for i in range(len(train)):
  if len(train["Processed text"][i]) == 1: 
    if len(train["Processed text"][i][0]) > 512: 
      print(i)
      train["Processed text"][i] = train["Processed text"][i][0].split("  ")
# Out:
# 4
# /var/folders/dk/5xxlbv9n6xngmfm92w8343_40000gp/T/ipykernel_88264/4082502854.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train["Processed text"][i] = train["Processed text"][i][0].split("  ")
# ...

# %%
len(train["Processed text"][4][0])
# Out:
# 34

# %%
samples = [bcbert_encoder(train["Processed text"][i]) for i in range(len(train))]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ...

# %%
samples_corrected = [mean_sample(samples[i]) for i in range(len(samples))]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# Standardize the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(samples_corrected)

# %%
# Create PCA object
pca = PCA(n_components=2)

# Fit PCA on the scaled data
principal_components = pca.fit_transform(data_scaled)

# Convert principal components to a DataFrame for better readability
principal_df = pd.DataFrame(data=principal_components, columns=['x', 'y'])

# Output the principal components
principal_df
# Out:
#              x          y
# 0   -13.931025  -2.275863
# 1    -6.079347   6.658774
# 2    67.462954  -3.028567
# 3   -11.294629  -2.328436
# 4    34.950224  77.128080
# ..         ...        ...
# 148  -4.911477  -2.737706
# 149  23.309101  15.540513
# 150 -13.806540  -0.848009
# 151  -4.022587  -4.731912
# 152  -8.132229  -0.269109
#
# [153 rows x 2 columns]

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.5829666  0.10297874]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(principal_df["x"][label1], principal_df['y'][label1],s=20)

# %%
label1 = [i for i in range(len(train)) if train["Label"][i]==1]
label2 = [i for i in range(len(train)) if train["Label"][i]==2]
label3 = [i for i in range(len(train)) if train["Label"][i]==3]
label4 = [i for i in range(len(train)) if train["Label"][i]==4]

# %%
plt.scatter(principal_df["x"][label1], principal_df['y'][label1],s=20)
plt.scatter(principal_df["x"][label2], principal_df['y'][label2],s=20)
plt.scatter(principal_df["x"][label3], principal_df['y'][label3],s=20)
plt.scatter(principal_df["x"][label4], principal_df['y'][label4],s=20)
